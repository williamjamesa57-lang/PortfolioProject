# %%
import utils.data_loader as data_loader
import earnings_predictor.src.features.nlp_extractor as nlp_extractor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import utils.data_loader as data_loader
#       2 import earnings_predictor.src.features.nlp_extractor as nlp_extractor
#
# ModuleNotFoundError: No module named 'utils'

# %%
loader = data_loader.DataLoader()
nlp = nlp_extractor.NLPExtractor(loader)
result = nlp.extract_features()
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 loader = data_loader.DataLoader()
#       2 nlp = nlp_extractor.NLPExtractor(loader)
#       3 result = nlp.extract_features()
#
# NameError: name 'data_loader' is not defined
