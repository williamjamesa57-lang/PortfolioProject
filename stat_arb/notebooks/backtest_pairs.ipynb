# %%
import stat_arb.src.features.cointegrations as cointegrations
import utils.data_loader as data_loader

# %%
data_loader = data_loader.DataLoader()
cointegrations = cointegrations.CointegrationEngine(data_loader)
